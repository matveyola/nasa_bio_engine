# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_csv("../data/exmpl_for_clustering_with_summaries.csv")
print(df["summary"].head(5))
# Out:
# 0                                                                                                                                                                                                                                                                                           Дослідження було спрямоване на вивчення механізмів адаптації фізіологічних систем під час тривалого перебування в мікрогравітації. Для цього було розроблено експериментальну програму із застосуванням мишей, які були піддані умовам мікрогравітації протягом певного періоду часу. У дослідах поєднувалися фізіологічні, біохімічні та генетичні дослідження, щоб вивчити вплив мікрогравітації на різні системи організму мишей. Результати досліджень допомогли краще зрозуміти механізми адаптації організму до умов мікрогравітації та потенційно відкрили нові можливості для розвитку нових методів лікування та профілактики захворювань, пов'язаних із мікрогравітацією. Також було встановлено вплив мікрогравітації на фізіол
# ...

# %%
p
